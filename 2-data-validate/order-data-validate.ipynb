# %% [markdown]
# ### Connect postgresql database

# %%
import pandas as pd
from sqlalchemy import create_engine

# 数据库配置
username = "XXXXXX"
password = "YYYYYY"
host = "localhost"
port = 5432
database = "eyewear-data"

# 创建连接
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# 查询数据
sql = """
SELECT *
FROM "Order";
"""

df = pd.read_sql(sql, engine)

# 查看数据
df
# Out:
#         order_id  customer_id     order_m3_code          order_date  \
# 0              1        31227  RBORD20231000001 2023-03-05 04:04:51
# 1              2        93491  RBORD20231000002 2023-02-20 04:44:44
# 2              3       145346  RBORD20231000003 2023-02-19 11:54:05
# 3              4       119747  RBORD20231000004 2023-02-23 07:24:55
# 4              5       156572  RBORD20231000005 2023-02-17 20:39:30
# ...          ...          ...               ...                 ...
# 499995    499996        52812  RBORD20244499996 2024-12-15 21:14:46
# 499996    499997       116238  RBORD20244499997 2024-10-26 11:03:03
# 499997    499998        56429  RBORD20244499998 2024-11-20 05:32:02
# 499998    499999        61500  RBORD20244499999 2024-10-30 19:05:05
# 499999    500000       128706  RBORD20244500000 2024-11-30 23:31:55
#
#              approval_date       delivery_date order_status  shipping_fee  \
# 0      2023-03-06 04:04:51 2023-03-13 04:04:51    Completed           0.0
# 1      2023-02-21 04:44:44 2023-02-28 04:44:44    Completed           0.0
# 2      2023-02-19 11:54:05 2023-02-28 11:54:05      Pending           0.0
# 3      2023-02-23 07:24:55 2023-03-01 07:24:55      Pending           0.0
# 4      2023-02-17 20:39:30 2023-02-23 20:39:30    Completed           0.0
# ...                    ...                 ...          ...           ...
# 499995 2024-12-16 21:14:46 2024-12-18 21:14:46    Completed          10.0
# 499996 2024-10-29 11:03:03 2024-11-02 11:03:03    Completed           0.0
# 499997 2024-11-23 05:32:02 2024-11-27 05:32:02    Completed          10.0
# 499998 2024-11-02 19:05:05 2024-11-04 19:05:05    Completed           0.0
# 499999 2024-12-01 23:31:55 2024-12-11 23:31:55      Shipped           0.0
#
#         tax_amount  total_price_before_discount_and_tax  \
# 0            36.23                               476.66
# 1            13.78                               176.95
# 2            51.99                               547.28
# 3            31.01                               326.39
# 4            14.30                               150.53
# ...            ...                                  ...
# 499995       51.36                               750.85
# 499996       42.88                               451.32
# 499997       18.22                               295.09
# 499998       92.40                               972.59
# 499999       17.53                               184.55
#
#         total_price_before_tax  total_price_after_tax  is_shipping_free  \
# 0                       381.32                 417.55              True
# 1                       145.10                 158.88              True
# 2                       547.28                 599.27              True
# 3                       326.39                 357.40              True
# 4                       150.53                 164.83              True
# ...                        ...                    ...               ...
# 499995                  550.61                 601.97             False
# 499996                  451.32                 494.20              True
# 499997                  201.81                 220.03             False
# 499998                  972.59                1064.99              True
# 499999                  184.55                 202.08              True
#
#         is_reward_points  is_insurance  store_id  campaign_id
# 0                   True         False        31          1.0
# 1                   True         False       101          3.0
# 2                  False         False        34          NaN
# 3                   True         False        86          NaN
# 4                  False         False        88          NaN
# ...                  ...           ...       ...          ...
# 499995              True         False        82         25.0
# 499996             False         False        83          NaN
# 499997             False         False        46         26.0
# 499998              True         False        75          NaN
# 499999              True         False        26          NaN
#
# [500000 rows x 17 columns]

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_m3_code', 'order_date',
#        'approval_date', 'delivery_date', 'order_status', 'shipping_fee',
#        'tax_amount', 'total_price_before_discount_and_tax',
#        'total_price_before_tax', 'total_price_after_tax', 'is_shipping_free',
#        'is_reward_points', 'is_insurance', 'store_id', 'campaign_id'],
#       dtype='object')

# %%
import numpy as np
np.sort(df['campaign_id'].unique())
# Out:
# array([55., 56., 57., 58., 59., 60., 61., 62., 63., 64., 65., 66., 67.,
#        68., 69., 70., 71., 72., 73., 74., 75., 76., 77., 78., 79., 80.,
#        81., nan])

# %%
df['campaign_id'].nunique()
# Out:
# 27
