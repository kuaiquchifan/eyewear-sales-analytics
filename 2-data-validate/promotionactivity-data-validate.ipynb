# %% [markdown]
# ### Connect postgresql database

# %%
import pandas as pd
from sqlalchemy import create_engine

# 数据库配置
username = "XXXXXX"
password = "YYYYYY"
host = "localhost"
port = 5432
database = "eyewear-data"

# 创建连接
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# 查询数据
sql = """
SELECT *
FROM "PromotionActivity";
"""

df = pd.read_sql(sql, engine)

# 查看数据
df
# Out:
#     campaign_id campaign_type                     campaign_name  \
# 0            55       Holiday      2023 New Year Spectacle Sale
# 1            56       Holiday   2023 Valentine’s Day Lens Event
# 2            57      Seasonal                  2023 Spring Sale
# 3            58        Member         2023 Easter Eye Care Gift
# 4            59       Holiday         2023 Mother’s Day Special
# 5            60      Seasonal         2023 Summer Sunglass Sale
# 6            61       Holiday    2023 July 4 Independence Event
# 7            62      Seasonal      2023 August Summer Clearance
# 8            63      Seasonal               2023 Back to School
# 9            64       Holiday        2023 Halloween Frame Treat
# 10           65       Holiday                 2023 Black Friday
# 11           66       Holiday          2023 Christmas Gift Sale
# 12           67       Holiday         2024 New Year Celebration
# 13           68       Holiday   2024 Valentine’s Day Lens Event
# 14           69      Seasonal                  2024 Spring Sale
# 15           70        Member         2024 Easter Eye Care Gift
# 16           71       Holiday         2024 Mother’s Day Special
# 17           72      Seasonal           2024 Summer Shield Sale
# 18           73       Holiday     2024 July 4 Independence Sale
# 19           74      Seasonal      2024 August Summer Clearance
# 20           75      Seasonal               2024 Back to School
# 21           76      Seasonal              2024 Fall Frame Fest
# 22           77       Holiday  2024 Singles Day Spectacle Event
# 23           78       Holiday                 2024 Black Friday
# 24           79       Holiday          2024 Christmas Gift Sale
# 25           80      Seasonal           2024 Year-End Clearance
# 26           81        Member     2024 Anniversary Member Drive
#
#        target_audience         region  start_date    end_date  \
# 0        All Customers  United States  2023-01-01  2023-01-10
# 1   Existing Customers  United States  2023-02-10  2023-02-18
# 2        All Customers  United States  2023-03-15  2023-03-25
# 3   Existing Customers  United States  2023-04-01  2023-04-10
# 4        All Customers  United States  2023-05-01  2023-05-14
# 5        All Customers  United States  2023-06-01  2023-06-15
# 6        All Customers  United States  2023-07-01  2023-07-07
# 7        All Customers  United States  2023-08-10  2023-08-20
# 8        New Customers  United States  2023-09-01  2023-09-15
# 9        VIP Customers  United States  2023-10-20  2023-10-31
# 10       All Customers  United States  2023-11-20  2023-11-28
# 11       All Customers  United States  2023-12-01  2023-12-25
# 12       All Customers  United States  2024-01-01  2024-01-10
# 13  Existing Customers  United States  2024-02-10  2024-02-18
# 14       All Customers  United States  2024-03-15  2024-03-25
# 15  Existing Customers  United States  2024-04-01  2024-04-10
# 16       All Customers  United States  2024-05-01  2024-05-14
# 17       All Customers  United States  2024-06-01  2024-06-16
# 18       All Customers  United States  2024-07-01  2024-07-07
# 19       All Customers  United States  2024-08-10  2024-08-20
# 20       New Customers  United States  2024-09-01  2024-09-15
# 21       VIP Customers  United States  2024-10-10  2024-10-18
# 22       New Customers  United States  2024-11-01  2024-11-11
# 23       All Customers  United States  2024-11-22  2024-11-28
# 24       All Customers  United States  2024-12-01  2024-12-25
# 25       All Customers  United States  2024-12-26  2024-12-31
# 26       VIP Customers  United States  2024-10-10  2024-10-15
#
#       discount_type  discount_value  min_purchase_amount  expected_sales_lift  \
# 0        Percentage            0.20                300.0                 1.12
# 1      Fixed Amount           50.00                500.0                 1.18
# 2        Percentage            0.18                  0.0                 1.10
# 3         Free Gift            0.00                600.0                 1.08
# 4        Percentage            0.22                400.0                 1.16
# 5        Percentage            0.15                  0.0                 1.09
# 6      Fixed Amount           80.00                500.0                 1.13
# 7        Percentage            0.20                  0.0                 1.11
# 8   Buy One Get One            0.00                300.0                 1.20
# 9        Percentage            0.18                  0.0                 1.07
# 10     Fixed Amount          100.00                600.0                 1.28
# 11       Percentage            0.25                  0.0                 1.22
# 12       Percentage            0.22                300.0                 1.18
# 13     Fixed Amount           60.00                500.0                 1.20
# 14       Percentage            0.20                  0.0                 1.14
# 15        Free Gift            0.00                500.0                 1.09
# 16       Percentage            0.24                  0.0                 1.19
# 17       Percentage            0.18                  0.0                 1.12
# 18     Fixed Amount           80.00                500.0                 1.15
# 19       Percentage            0.22                  0.0                 1.13
# 20  Buy One Get One            0.00                300.0                 1.21
# 21       Percentage            0.19                  0.0                 1.11
# 22       Percentage            0.30                  0.0                 1.35
# 23     Fixed Amount          120.00                600.0                 1.30
# 24       Percentage            0.28                  0.0                 1.25
# 25       Percentage            0.35                  0.0                 1.18
# 26        Free Gift            0.00                400.0                 1.14
#
#        status
# 0   completed
# 1   completed
# 2   completed
# 3   completed
# 4   completed
# 5   completed
# 6   completed
# 7   completed
# 8   completed
# 9   completed
# 10  completed
# 11  completed
# 12     active
# 13     active
# 14     active
# 15     active
# 16     active
# 17     active
# 18     active
# 19     active
# 20     active
# 21     active
# 22     active
# 23     active
# 24     active
# 25     active
# 26     active

# %%
df.columns
# Out:
# Index(['campaign_id', 'campaign_type', 'campaign_name', 'target_audience',
#        'region', 'start_date', 'end_date', 'discount_type', 'discount_value',
#        'min_purchase_amount', 'expected_sales_lift', 'status'],
#       dtype='object')

# %%
import numpy as np
np.sort(df['campaign_id'].unique())
# Out:
# array([55., 56., 57., 58., 59., 60., 61., 62., 63., 64., 65., 66., 67.,
#        68., 69., 70., 71., 72., 73., 74., 75., 76., 77., 78., 79., 80.,
#        81., nan])
