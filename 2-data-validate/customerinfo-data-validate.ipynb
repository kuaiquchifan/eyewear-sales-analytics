# %% [markdown]
# ### Connect postgresql database

# %%
import pandas as pd
from sqlalchemy import create_engine

# 数据库配置
username = "XXXXXX"
password = "YYYYYY"
host = "localhost"
port = 5432
database = "eyewear-data"

# 创建连接
engine = create_engine(
    f"postgresql+psycopg2://{username}:{password}@{host}:{port}/{database}"
)

# 查询数据
sql = """
SELECT *
FROM "CustomerInfo";
"""

df = pd.read_sql(sql, engine)

# 查看数据
df
# Out:
#         customer_id customer_m3_code      customer_name  gender  age  \
# 0            167055       CUST-17054        Tyler Terry  Female   18
# 1            167056       CUST-17055      Renee Griffin    Male   33
# 2            167057       CUST-17056     Cynthia Nelson    Male   37
# 3            167058       CUST-17057        Sara Moreno    Male   26
# 4            167059       CUST-17058  Christopher White    Male   20
# ...             ...              ...                ...     ...  ...
# 159995       167050       CUST-17049     Michael Nelson    Male   45
# 159996       167051       CUST-17050         David Ward  Female   58
# 159997       167052       CUST-17051      Blake Gilbert  Female   35
# 159998       167053       CUST-17052     Michelle Clark  Female   25
# 159999       167054       CUST-17053    Dennis Thompson    Male   32
#
#         birth_date region country  city registration_date last_purchase_date  \
# 0       2007-08-24   None    None  None        2017-01-27               None
# 1       1993-03-06   None    None  None        2015-02-10               None
# 2       1988-12-16   None    None  None        2020-10-21               None
# 3       2000-07-03   None    None  None        2024-05-03               None
# 4       2006-06-30   None    None  None        2019-11-10               None
# ...            ...    ...     ...   ...               ...                ...
# 159995  1981-07-07   None    None  None        2019-10-20               None
# 159996  1967-10-05   None    None  None        2023-06-17               None
# 159997  1991-06-24   None    None  None        2023-03-18               None
# 159998  2000-11-26   None    None  None        2024-03-05               None
# 159999  1993-09-13   None    None  None        2023-07-25               None
#
#         total_orders  total_spend customer_type customer_hierarchy  \
# 0                  0          0.0          None               None
# 1                  0          0.0          None               None
# 2                  0          0.0          None               None
# 3                  0          0.0          None               None
# 4                  0          0.0          None               None
# ...              ...          ...           ...                ...
# 159995             0          0.0          None               None
# 159996             0          0.0          None               None
# 159997             0          0.0          None               None
# 159998             0          0.0          None               None
# 159999             0          0.0          None               None
#
#        channel_source preferred_store_id  is_active
# 0                None               None       True
# 1                None               None       True
# 2                None               None       True
# 3                None               None       True
# 4                None               None       True
# ...               ...                ...        ...
# 159995           None               None       True
# 159996           None               None       True
# 159997           None               None       True
# 159998           None               None       True
# 159999           None               None       True
#
# [160000 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['customer_id', 'customer_m3_code', 'customer_name', 'gender', 'age',
#        'birth_date', 'region', 'country', 'city', 'registration_date',
#        'last_purchase_date', 'total_orders', 'total_spend', 'customer_type',
#        'customer_hierarchy', 'channel_source', 'preferred_store_id',
#        'is_active'],
#       dtype='object')

# %%
# 查看亚太区的数据
asia_pacific_df = df[df['region']=='Asia-Pacific']

asia_pacific_df['country'].drop_duplicates().to_list()
# Out:
# ['Korea, Republic of', 'Australia', 'Singapore', 'China', 'India', 'Japan']

# %%
# 查看 EMEA 区的数据
emea_df = df[df['region']=='EMEA']
emea_df['country'].drop_duplicates().to_list()
# Out:
# ['Germany',
#  'Italy',
#  'France',
#  'Spain',
#  'Nigeria',
#  'South Africa',
#  'United Kingdom',
#  'Egypt']

# %%
north_america_df = df[df['region']=='North America']
north_america_df['country'].drop_duplicates().to_list()
# Out:
# ['Canada', 'United States', 'Mexico']

# %%
latin_america_df = df[df['region']=='Latin America']
latin_america_df['country'].drop_duplicates().to_list()
# Out:
# ['Brazil', 'Peru', 'Argentina', 'Chile', 'Colombia']

# %%
# 关闭数据库连接
engine.dispose()
