# %%
import safetensors
print(safetensors.__version__)
# Out:
# 0.8.0

# %%
from transformers import AutoModelForSequenceClassification


model_path = r"D:\huggingface_models\cardiffnlp-twitter-roberta"

output_path = r"D:\huggingface_models\cardiffnlp-twitter-roberta-safe"


model = AutoModelForSequenceClassification.from_pretrained(
    model_path,
    use_safetensors=False,
    # weights_only=False
)


model.save_pretrained(
    output_path,
    safe_serialization=True
)

print("Conversion finished!")
# Out:
# Some weights of the model checkpoint at D:\huggingface_models\cardiffnlp-twitter-roberta were not used when initializing RobertaForSequenceClassification: ['roberta.pooler.dense.bias', 'roberta.pooler.dense.weight']
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Conversion finished!

# %%
import transformers
print(transformers.__version__)
# Out:
# 4.45.2
