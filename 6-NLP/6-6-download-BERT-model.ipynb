# %%
from huggingface_hub import snapshot_download

snapshot_download(
    repo_id="cardiffnlp/twitter-roberta-base-sentiment-latest",
    local_dir=r"D:\huggingface_models\cardiffnlp-twitter-roberta"
)
